# %% [markdown]
# ## Implementation

# %% [markdown]
# The implementation of the ideas discussed in the paper required utilization of programming tools like python and R. We have used python for mazority of the tasks and R for few tasks based on the ease of implementation. In the following sections you will find the detailed documentation of the code for various tasks like generating networks, simulation and analysis of the results.
